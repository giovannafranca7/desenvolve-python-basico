# %%
import random

aleatorios = []
for i in range(20):
    valor = random.randint(-100, 100)
    aleatorios.append(valor)
    print(sorted(aleatorios))
    print(aleatorios)
    print("O maior valor está no índice: ",aleatorios.index (max(aleatorios)))
    print("O menor valor está no índice: ",aleatorios.index (min(aleatorios)))
# Out:
# [7]
# [7]
# O maior valor está no índice:  0
# O menor valor está no índice:  0
# [-91, 7]
# [7, -91]
# O maior valor está no índice:  0
# O menor valor está no índice:  1
# [-91, -48, 7]
# [7, -91, -48]
# O maior valor está no índice:  0
# O menor valor está no índice:  1
# [-91, -65, -48, 7]
# [7, -91, -48, -65]
# O maior valor está no índice:  0
# O menor valor está no índice:  1
# [-91, -80, -65, -48, 7]
# [7, -91, -48, -65, -80]
# O maior valor está no índice:  0
# O menor valor está no índice:  1
# [-91, -80, -65, -48, 7, 45]
# [7, -91, -48, -65, -80, 45]
# O maior valor está no índice:  5
# O menor valor está no índice:  1
# [-91, -80, -65, -48, -12, 7, 45]
# [7, -91, -48, -65, -80, 45, -12]
# O maior valor está no índice:  5
# O menor valor está no índice:  1
# [-91, -80, -65, -48, -12, 7, 45, 57]
# [7, -91, -48, -65, -80, 45, -12, 57]
# O maior valor está no índice:  7
# O menor valor está no índice:  1
# [-91, -80, -65, -48, -12, 7, 45, 57, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -80, -65, -48, -12, 7, 45, 57, 75, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -80, -65, -52, -48, -12, 7, 45, 57, 75, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -80, -65, -52, -48, -12, 7, 39, 45, 57, 75, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -80, -78, -65, -52, -48, -12, 7, 39, 45, 57, 75, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -89, -80, -78, -65, -52, -48, -12, 7, 39, 45, 57, 75, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -89, -80, -78, -65, -52, -48, -12, 7, 39, 45, 57, 75, 83, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89, 83]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-91, -89, -80, -78, -65, -52, -48, -12, 7, 39, 40, 45, 57, 75, 83, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89, 83, 40]
# O maior valor está no índice:  8
# O menor valor está no índice:  1
# [-100, -91, -89, -80, -78, -65, -52, -48, -12, 7, 39, 40, 45, 57, 75, 83, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89, 83, 40, -100]
# O maior valor está no índice:  8
# O menor valor está no índice:  16
# [-100, -91, -89, -80, -79, -78, -65, -52, -48, -12, 7, 39, 40, 45, 57, 75, 83, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89, 83, 40, -100, -79]
# O maior valor está no índice:  8
# O menor valor está no índice:  16
# [-100, -99, -91, -89, -80, -79, -78, -65, -52, -48, -12, 7, 39, 40, 45, 57, 75, 83, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89, 83, 40, -100, -79, -99]
# O maior valor está no índice:  8
# O menor valor está no índice:  16
# [-100, -99, -91, -89, -80, -79, -78, -65, -52, -48, -12, 7, 13, 39, 40, 45, 57, 75, 83, 87]
# [7, -91, -48, -65, -80, 45, -12, 57, 87, 75, -52, 39, -78, -89, 83, 40, -100, -79, -99, 13]
# O maior valor está no índice:  8
# O menor valor está no índice:  16
