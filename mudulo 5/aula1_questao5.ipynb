# %%
import emoji

# Exibindo a lista de emojis disponíveis
print("Emojis disponíveis:")
print("❤️ - :red_heart:")
print("👍 - :thumbs_up:")
print("🤔 - :thinking_face:")
print("🥳 - :partying_face:")

# Solicitando a frase do usuário
frase = input("Digite uma frase e ela será emojizada:\n")

# Emojizando a frase
frase_emojizada = emoji.emojize(frase)

# Exibindo a frase emojizada
print("Frase emojizada:")
print(frase_emojizada)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import emoji
#       3 # Exibindo a lista de emojis disponíveis
#       4 print("Emojis disponíveis:")
#
# ModuleNotFoundError: No module named 'emoji'
